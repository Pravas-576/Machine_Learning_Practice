# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset("iris")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %% [markdown]
# ### Univariate Analysis

# %%
df_setosa = df.loc[df['species']=='setosa']
df_verginica = df.loc[df['species']=='verginica']
df_versicolor = df.loc[df['species']=='versicolor']

# %%
plt.plot(df_setosa['sepal_length'], np.zeros_like(df_setosa['sepal_length']), 'o')
plt.plot(df_verginica['sepal_length'], np.zeros_like(df_verginica['sepal_length']), 'o')
plt.plot(df_versicolor['sepal_length'], np.zeros_like(df_versicolor['sepal_length']), 'o')
plt.xlabel("sepal length")
plt.show()

# %% [markdown]
# ### Bivariate Analysis

# %%
sns.FacetGrid(df, hue = 'species', size = 5).map(plt.scatter, "sepal_length", "sepal_width").add_legend();
plt.show()
# Out:
# C:\Users\Pravas\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Multivariate Analysis

# %%
sns.pairplot(df, hue = 'species', size = 4)
# Out:
# C:\Users\Pravas\anaconda3\lib\site-packages\seaborn\axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
